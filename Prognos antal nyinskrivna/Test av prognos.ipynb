# %%
from prognos_antal_nyinskrivna import read_and_prep_data
from prognos_antal_nyinskrivna import create_ForecastTest
from prognos_antal_nyinskrivna import run_ForecastTest

# data kommer ifrån intensivvårdsregistret (SIR) https://portal.icuregswe.org/utdata/sv/report/demo.vtfstart?filter=f1c6d908-257f-424b-b6f2-822221495c93
df_to_20211226 = read_and_prep_data('tidsserie_SIR1.csv') 
df_to_20170208 = read_and_prep_data('tidsserie_SIR2.csv')

# %%
# Test 1
test1 = create_ForecastTest(
    df=df_to_20170208, 
    pred_period_start_date_str= '2017-01-11', 
    prediction_period_str = '15 days')

run_ForecastTest(test1)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# period of df_forecast: 2017-01-11 to 2017-01-25
# period of df_train: 2014-12-02 to 2017-01-10
# period of df: 2014-12-02 to 2017-02-08

# %%
# Test 2
test2 = create_ForecastTest(
    df=df_to_20211226, 
    pred_period_start_date_str= '2021-11-28', 
    prediction_period_str = '15 days')

run_ForecastTest(test2)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# period of df_forecast: 2021-11-28 to 2021-12-12
# period of df_train: 2020-01-01 to 2021-11-27
# period of df: 2020-01-01 to 2021-12-26
